# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Exercise 2: DataScienceEcosystem.ipynb</h1>

# %% [markdown]
# <h1>Exercise 3: Create a markdown cell for an introduction. (1 pt)</h1>
#
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# <strong>Objectives:</strong>
#
# List popular languages that Data Scientists use
#
# List commonly used libraries used by Data Scientists.
#
# Comment on Data Science tools

# %% [markdown]
# <h1>Exercise 4 - Create a markdown cell to list data science languages. (3 pts)</h1>
#
# Some of the popular languages that Data Scientists use are:
# <h3>
# <ol>
# <li>Python.</li>
#
# <li>R.</li>
#
# <li>SQL.</li>
#
# <li>Java.</li>
#
# <li>Julia.</li>
#
# <li>Scala.</li>
#
# <li>C/C++.</li>
#
# <li>JavaScript</li>
# </ol>
# </h3>

# %% [markdown]
# <h1>Exercise 5 - Create a markdown cell to list data science libraries.(3 pts)</h1>
#
# Some of the commonly used libraries used by Data Scientists include:
# <h3>
# <ol>
# <li>TensorFlow.</li>
#
# <li>NumPy.</li>
#
# <li>SciPy.</li>
#
# <li>Pandas.</li>
#
# <li>Matplotlib.</li>
#
# <li>Keras.</li>
#
# <li>SciKit-Learn.</li>
#
# <li>PyTorch.</li>
# </h3>

# %% [markdown]
# <h1>Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)</h1>
#
# <h3>Data Science Tools</h3>
#
# SAS.
#
# Hadoop
#
# Apache Spark

# %% [markdown]
# <h1>Exercise 7 - Create a markdown cell introducing arithmetic expression examples</h1>
#
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %% [markdown]
# <h1>Exercise 8 - Create a code cell to multiply and add numbers.(2 pts)</h1>

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# <h1>Exercise 9 - Create a code cell to convert minutes to hours</h1>

# %%
days = 0
hours = 0
mins = 0

time = 200
leftover_minutes = time % 1440
hours = leftover_minutes / 60
print(str(days) + " days, " + str(hours) + " hours, " + str(mins) +  " mins. ")
# Out:
# 0 days, 3.3333333333333335 hours, 0 mins.

# %% [markdown]
# <h1>Exercise 10 -Insert a markdown cell to list Objectives</h1>

# %% [markdown]
# <strong>Objectives:</strong>
#
# Listed popular languages that Data Scientists use
# <ol>
# <li>Python.</li>
#
# <li>R.</li>
#
# <li>SQL.</li>
# </ol>
#
# Listed commonly used libraries used by Data Scientists.
#
# <ol>
# <li>TensorFlow.</li>
#
# <li>NumPy.</li>
#
# <li>SciPy.</li>
# </ol>

# %% [markdown]
# <h1>Exercise 11 - Create a markdown cell to indicate the Author’s name.</h1>
#
# <h3>Sarthak Chauhan</h3>
